# %%
# Set the name you want the model to be saved as (e.g. "llama3")
MODEL_NAME = "llama3"
# Set the URL of the model you want to use (e.g. "meta-llama/Meta-Llama-3-70B-Instruct")
MODEL_URL = "meta-llama/Meta-Llama-3-70B-Instruct"
# Set the API key of the provider of the model you want to use (e.g. "hf_AbCdEfGhIjKlMnOpQrStUvWxYzAbCdEfGh")
KEY = "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"
# Choose a provider of the API among "huggingface" or "openai"
PROVIDER = "huggingface"

# %%
from src.model_client import ModelClient

model_client = ModelClient(MODEL_NAME, MODEL_URL, KEY, PROVIDER)

# %%
# Test the connection
quack = model_client.generate_text("Quack", max_new_tokens=1)
print(quack)
# Out:
# ery

# %%
from user_interface_utils import evaluate_comprehension_questions

n_games = 1
n_iterations = 2
history_window_size = n_iterations
checkpoint = 0

# You can find the raw results in the folder "out / <MODEL_NAME> / comprehension_questions"
evaluate_comprehension_questions(model_client, n_games=n_games, n_iterations=n_iterations, history_window_size=history_window_size, checkpoint=checkpoint)
# Out:
# Running llama3 against a random opponent in 1 games of 2 iterations each.
# Game 1
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\strategies\one_vs_one_pd_llm_strategy.py:86: UserWarning: 'action' in answer: {}. Returning 'Defect' action as 0.
#   warnings.warn(f"{str(e)} in answer: {answer}. Returning 'Defect' action as 0.")
# Time elapsed: 0:01:16
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\numpy\core\_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\numpy\core\_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2244: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2245: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
from user_interface_utils import plot_comprehension_questions_results

plot_comprehension_questions_results(MODEL_NAME, n_games, n_iterations, history_window_size)
# Out:
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\user_interface_utils.py:90: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(x_labels, rotation=90, fontsize=18)
