# %%
# Set the name you want the model to be saved as (e.g. "llama3")
MODEL_NAME = "llama3_test"
# Set the URL of the model you want to use (e.g. "meta-llama/Meta-Llama-3-70B-Instruct")
MODEL_URL = "meta-llama/Meta-Llama-3-70B-Instruct"
# Set the API key of the provider of the model you want to use (e.g. "hf_AbCdEfGhIjKlMnOpQrStUvWxYzAbCdEfGh")
KEY = "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"
# Choose a provider of the API among "huggingface" or "openai"
PROVIDER = "huggingface"

# %%
from src.model_client import ModelClient

model_client = ModelClient(MODEL_NAME, MODEL_URL, KEY, PROVIDER)

# %%
from user_interface_utils import get_comprehension_questions_dir

n_games = 2
n_iterations = 3
history_window_size = 1
checkpoint = 0

out_dir = get_comprehension_questions_dir(MODEL_NAME, n_games, n_iterations, history_window_size)
print(out_dir)
# Out:
# out\analysis\llama3_test\comprehension_questions\g2_i3_w1

# %%
from user_interface_utils import evaluate_comprehension_questions, create_csv_comprehension_questions_results

evaluate_comprehension_questions(out_dir, model_client, n_games=n_games, n_iterations=n_iterations, history_window_size=history_window_size, checkpoint=checkpoint)

create_csv_comprehension_questions_results(out_dir, n_games)
# Out:
# Running llama3_test as 'A' against RND as 'B' in 2 games of 3 iterations each with 1 window size. Asking comprehension questions.
# Game 1
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\utils.py:54: UserWarning: No JSON object found in the input string:
#  answer: ["Cooperate", "Defect"]. Returning None.
#   warnings.warn(f"No JSON object found in the input string:\n {string}. Returning None.")
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\checkers\checker.py:80: UserWarning: Could not find a valid JSON object in the generated text: answer: ["Cooperate", "Defect"]. Returning entire generated text.
#   warnings.warn(f"Could not find a valid JSON object in the generated text: {generated_text}. Returning entire generated text.")
# Time elapsed: 0:01:31
# Game 2
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\checkers\checker.py:77: UserWarning: Error 'answer'. No key 'answer' in JSON: {}. Returning entire generated text.
#   warnings.warn(f"Error {str(e)}. No key 'answer' in JSON: {json_object}. Returning entire generated text.")
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\utils.py:54: UserWarning: No JSON object found in the input string:
#  answer: 0. Returning None.
#   warnings.warn(f"No JSON object found in the input string:\n {string}. Returning None.")
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\checkers\checker.py:80: UserWarning: Could not find a valid JSON object in the generated text: answer: 0. Returning entire generated text.
#   warnings.warn(f"Could not find a valid JSON object in the generated text: {generated_text}. Returning entire generated text.")
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\utils.py:54: UserWarning: No JSON object found in the input string:
#  answer: 1. Returning None.
#   warnings.warn(f"No JSON object found in the input string:\n {string}. Returning None.")
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\src\checkers\checker.py:80: UserWarning: Could not find a valid JSON object in the generated text: answer: 1. Returning entire generated text.
#   warnings.warn(f"Could not find a valid JSON object in the generated text: {generated_text}. Returning entire generated text.")
# Time elapsed: 0:03:17
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2244: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2245: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
from user_interface_utils import plot_comprehension_questions_results

plot_comprehension_questions_results(out_dir, MODEL_NAME)
# Out:
# C:\Users\fonta\PycharmProjects\masters_thesis_PoliMi_ITU\user_interface_utils.py:129: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(x_labels, rotation=90, fontsize=18)
