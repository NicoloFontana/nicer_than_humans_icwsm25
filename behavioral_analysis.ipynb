# %%
# Set the name you want the model to be saved as (e.g. "llama3")
MODEL_NAME = "llama3"
# Set the URL of the model you want to use (e.g. "meta-llama/Meta-Llama-3-70B-Instruct")
MODEL_URL = "meta-llama/Meta-Llama-3-70B-Instruct"
# Set the API key of the provider of the model you want to use (e.g. "hf_AbCdEfGhIjKlMnOpQrStUvWxYzAbCdEfGh")
KEY = "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"
# Choose a provider of the API among "huggingface" or "openai"
PROVIDER = "huggingface"

# %%
from src.model_client import ModelClient

model_client = ModelClient(MODEL_NAME, MODEL_URL, KEY, PROVIDER)

# %%
n_games = 2
n_iterations = 3
history_window_size = 1
checkpoint = 0

# %%
from user_interface_utils import compute_response_to_different_hostilities

compute_response_to_different_hostilities(model_client, n_games=n_games, n_iterations=n_iterations, history_window_size=history_window_size, checkpoint=checkpoint, already_run_against_ad=False)
# Out:
# URND00
# Running llama3 as 'A' against URND as 'B' in 2 games of 3 iterations each with 1 window size.
# Game 1
# Time elapsed: 0:00:01
# Game 2
# Time elapsed: 0:00:03
# URND01
# Running llama3 as 'A' against URND as 'B' in 2 games of 3 iterations each with 1 window size.
# Game 1
# Time elapsed: 0:00:01
# Game 2
# Time elapsed: 0:00:03
# URND02
# Running llama3 as 'A' against URND as 'B' in 2 games of 3 iterations each with 1 window size.
# Game 1
# Time elapsed: 0:00:01
# Game 2
# Time elapsed: 0:00:04
# Computing SFEM for run against URND00
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2244: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2245: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\optimize\_slsqp_py.py:437: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\optimize\_slsqp_py.py:441: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   g = append(wrapped_grad(x), 0.0)
# C:\Users\fonta\anaconda3\envs\masters_thesis_env\lib\site-packages\scipy\optimize\_slsqp_py.py:495: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   a_eq = vstack([con['jac'](x, *con['args'])
# Computing SFEM for run against URND01
# Computing SFEM for run against URND02
# Running RND as 'A' against URND as 'B' in 100 games of 5 iterations each with 5 window size.
# Time elapsed: 0:00:00
# Running RND as 'A' against URND as 'B' in 100 games of 5 iterations each with 5 window size.
# Time elapsed: 0:00:01
# Running RND as 'A' against URND as 'B' in 100 games of 5 iterations each with 5 window size.
# Time elapsed: 0:00:00

# %%
from user_interface_utils import plot_coop_probability_vs_urnd_alpha, plot_sfem_results_vs_urnd_alpha, plot_behavioral_profile_vs_urnd_alpha

plot_coop_probability_vs_urnd_alpha(MODEL_NAME, n_games, n_iterations, history_window_size)
plot_sfem_results_vs_urnd_alpha(MODEL_NAME, n_games, n_iterations, history_window_size)
plot_behavioral_profile_vs_urnd_alpha(MODEL_NAME, n_games, n_iterations, history_window_size)
